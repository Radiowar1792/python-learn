# %% [markdown]
# <a href="https://colab.research.google.com/github/Radiowar1792/python-learn/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input("choisi un number : ")
b = int(a) + 2
print(b)
# Out:
# choisi un number : 2
# 4
